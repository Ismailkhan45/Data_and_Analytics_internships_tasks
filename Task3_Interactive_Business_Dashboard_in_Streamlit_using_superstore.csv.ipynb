# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'superstore.csv')

# %%
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.columns

# %%
df.isnull().sum()

# %%
df.duplicated().sum()      #Checking Duplicate Values

# %%
# Correct Datatype
df['Order.Date'] = pd.to_datetime(df['Order.Date'])
df['Ship.Date'] = pd.to_datetime(df['Ship.Date'])

# %%
df[['Order.Date', 'Ship.Date']].dtypes

# %%
df['Sales'].sum()         #Total Sales

# %%
df['Profit'].sum()        #Total Profit

# %%
top5_customers = (df.groupby('Customer.Name')['Sales'].sum().sort_values(ascending=False).head(5))
top5_customers

# %%
df.groupby('Segment')[['Sales', 'Profit']].sum()     # Total Sales vs Total Profit
